# %% [markdown]
# # Máshin Lénin

# %% [markdown]
# Sci Kit Learn
# Estimador y Transformador

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

imp = SimpleImputer()

X = pd.DataFrame([[1, 3], [np.nan, 2], [8, 5.5]])
print(X)
# Out:
#      0    1
# 0  1.0  3.0
# 1  NaN  2.0
# 2  8.0  5.5

# %%
# Ejecuta pero no transforma el DataFrame
imp.fit(X)
# Out:
# SimpleImputer()

# %%
X_test = pd.DataFrame([[np.nan, 11], [4, np.nan], [8, 2], [np.nan, 1]])
print(X_test)
# Out:
#      0     1
# 0  NaN  11.0
# 1  4.0   NaN
# 2  8.0   2.0
# 3  NaN   1.0

# %%
# Llena los valores nulos con el promedio calculado en el primer DataFrame
print(imp.transform(X_test))
# Out:
# [[ 4.5 11. ]
#  [ 4.   3.5]
#  [ 8.   2. ]
#  [ 4.5  1. ]]

# %%
# Regresión lineal
import seaborn as sns

#dataset anscombe ya viene con seaborn
anscombe = sns.load_dataset("anscombe")

# %%
sns.lmplot(x = "x", y = "y", data=anscombe.query("dataset == 'I'"),
          ci = None, scatter_kws={"s": 80});

# %% [markdown]
# # Ecuación Normal

# %%
# Generamos un conjunto de datos lineal de forma aleatoria
import numpy as np
import matplotlib.pyplot as plt

X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

plt.plot(X, y, "b.")

# %%
X_b = np.c_[np.ones((100, 1)), X] 
mejores_params = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new] # add x0 = 1 to each instance 
y_predict_normal = X_new_b.dot(mejores_params)
y_predict_normal
# Out:
# array([[4.26506941],
#        [9.55758121]])

# %%
plt.plot(X, y, "b.")
plt.plot(X_new, y_predict_normal, "r-")

# %%
# Gradiente descendiente
